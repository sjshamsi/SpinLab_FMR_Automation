# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# %matplotlib ipympl
plt.style.use('seaborn')
plt.style.use('seaborn-colorblind')
# Out:
# C:\Users\plyslab\AppData\Local\Temp\ipykernel_7224\3458172300.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')
# C:\Users\plyslab\AppData\Local\Temp\ipykernel_7224\3458172300.py:2: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-colorblind')

# %%
from experiment import Experiment
E = Experiment()
# Out:
# Welcome to the FMR Experiment!
# You might want to update some experiment parameters.
# The parameters presently are:
#
# Field Sweep :	 None
# Frequency Swep :	 None
# PS Output Current (A) :	 2.09901
# PS Output Voltage (V) :	 -43.1992
# PS Output Mode (Current/Voltage) :	 Constant Current
# SG Frequency :	 FR03000000000HZ
# SG RF Output :	 On
# SG RF Output Level :	 LE-70.0DM
# LIA Sensitivity :	 0.0002
# LIA Time Constant :	 0.3
# Read Delay (s) :	 0.5
# Log File :	 C:\Users\plyslab\Desktop\SpinLab_FMR_Automation\Experiment_Logs\FMR_log_2023-6-6_14-56-13.log

# %%
E.field_sweep = np.linspace(33, 201, 50)
E.frequency_sweep = np.array([3])
E.SG.level = '3 DB'

# %%
E.begin_sweep()
# Out:
# The parameters presently are:
#
# Field Sweep :	 [ 33.          36.42857143  39.85714286  43.28571429  46.71428571
#   50.14285714  53.57142857  57.          60.42857143  63.85714286
#   67.28571429  70.71428571  74.14285714  77.57142857  81.
#   84.42857143  87.85714286  91.28571429  94.71428571  98.14285714
#  101.57142857 105.         108.42857143 111.85714286 115.28571429
#  118.71428571 122.14285714 125.57142857 129.         132.42857143
#  135.85714286 139.28571429 142.71428571 146.14285714 149.57142857
#  153.         156.42857143 159.85714286 163.28571429 166.71428571
#  170.14285714 173.57142857 177.         180.42857143 183.85714286
#  187.28571429 190.71428571 194.14285714 197.57142857 201.        ]
# Frequency Swep :	 [3]
# PS Output Current (A) :	 3.13626
# PS Output Voltage (V) :	 -40.707
# PS Output Mode (Current/Voltage) :	 Constant Current
# SG Frequency :	 FR03000000000HZ
# SG RF Output :	 On
# SG RF Output Level :	 LE3.0DM
# LIA Sensitivity :	 0.0002
# ...

# %%
df = pd.read_csv(r'C:\\Users\\plyslab\\Desktop\\3ghz_33-200Oe\\freq_3_ghz.csv')
df
# Out:
#     current_A    field_Oe         X         Y
# 0    0.049327   33.000000 -0.000036 -0.000045
# 1    0.051864   34.696970 -0.000039 -0.000051
# 2    0.054401   36.393939 -0.000038 -0.000053
# 3    0.056937   38.090909 -0.000039 -0.000050
# 4    0.059474   39.787879 -0.000042 -0.000050
# ..        ...         ...       ...       ...
# 95   0.290302  194.212121 -0.000045 -0.000053
# 96   0.292839  195.909091 -0.000045 -0.000053
# 97   0.295375  197.606061 -0.000045 -0.000052
# 98   0.297912  199.303030 -0.000046 -0.000052
# 99   0.300448  201.000000 -0.000045 -0.000052
#
# [100 rows x 4 columns]

# %%
plt.figure(figsize=(7,5))
plt.plot(df.field_Oe, df.X, label='Channel 1 (X)', alpha=0.5)
plt.scatter(df.field_Oe, df.X, s=1.5)

plt.plot(df.field_Oe, df.Y, label='Channel 2 (Y)', alpha=0.5)
plt.scatter(df.field_Oe, df.Y, s=1.5)

plt.title('Field Sweep, 33-201 Oe @ 3 GHz')
plt.xlabel('Field (Oe)')
plt.ylabel('Voltage (AU)')

plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Out:
# Using matplotlib backend: QtAgg

# %%
# %matplotlib
plt.plot(E.current_sweep, chA, label='Channel A')
plt.scatter(E.current_sweep, chA)
plt.plot(E.current_sweep, chB, label='Channel B')
plt.scatter(E.current_sweep, chB)
plt.title('FMR Curent Sweep 0.1-0.3 A, Frequency=4GHz, Channel A and B')
plt.xlabel('Current (A)')
plt.ylabel('Voltage (AU)')
plt.xlim(0.1, 0.3)
plt.legend()
plt.show()
# Out:
# Using matplotlib backend: QtAgg

# %%
# Sweeping Freq 3.75-5GHz, Curr = 0.33 A

E.frequency_sweep = np.linspace(3.75, 4.5, 100)
E.SG.level = '3 DB'
E.PS.CurrentMode()
E.PS.voltage = 20
E.PS.current = 0.33

chA = []
chB = []

for i, freq in enumerate(E.frequency_sweep):
    E.SG.frequency = '{} GHz'.format(freq)
    chA.append(E.LIA.X)
    chB.append(E.LIA.Y)

E.PS.current = 0

# %%
# %matplotlib
plt.plot(E.frequency_sweep, chA, label='Channel A')
plt.scatter(E.frequency_sweep, chA)
plt.plot(E.frequency_sweep, chB, label='Channel B')
plt.scatter(E.frequency_sweep, chB)
plt.title('FMR Frequency Sweep 3-4 GHz, Currnt=0.33 A, Channel A and B')
plt.xlabel('Frequency (GHz)')
plt.ylabel('Voltage (AU)')
# plt.xlim(0.1, 0.3)
plt.legend()
plt.show()
# Out:
# Using matplotlib backend: QtAgg

# %%
# Sweeping Freq 2.5-3.8GHz, Curr = 0.3 A

E.frequency_sweep = np.linspace(2, 6, 500)
E.SG.level = '3 DB'
E.PS.CurrentMode()
E.PS.voltage = 20
E.PS.current = 0.3

chA = []
chB = []

for i, freq in enumerate(E.frequency_sweep):
    E.SG.frequency = '{} GHz'.format(freq)
    time.sleep(0.5)
    chA.append(E.LIA.X)
    chB.append(E.LIA.Y)

E.PS.current = 0

# %%
plt.plot(E.frequency_sweep, chA, label='Channel A')
plt.scatter(E.frequency_sweep, chA)
plt.plot(E.frequency_sweep, chB, label='Channel B')
plt.scatter(E.frequency_sweep, chB)
plt.title('FMR Frequency Sweep 2-6 GHz, Currnt=0.3 A, Channel A and B')
plt.xlabel('Frequency (GHz)')
plt.ylabel('Voltage (AU)')
# plt.xlim(0.1, 0.3)
plt.legend()
plt.show()
# Out:
# Using matplotlib backend: <object object at 0x000001CC168427D0>

# %%
plt.plot(E.frequency_sweep, chA, label='Channel A')
plt.scatter(E.frequency_sweep, chA)
plt.plot(E.frequency_sweep, chB, label='Channel B')
plt.scatter(E.frequency_sweep, chB)
plt.title('FMR Frequency Sweep 2-6 GHz, Currnt=0.3 A, Channel A and B')
plt.xlabel('Frequency (GHz)')
plt.ylabel('Voltage (AU)')
# plt.xlim(0.1, 0.3)
plt.legend()
plt.show()

# %%
f_sweep = np.array(E.frequency_sweep)
chA = np.array(chA)
chB = np.array(chB)

# %%
np.save("./fsweep", f_sweep)

# %%
np.save("chA", chA)
np.save("chB", chB)

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
fsweep = np.load("fsweep.npy")
chA = np.load("chA.npy")
chB = np.load("chB.npy")

# %%
plt.plot(fsweep, chA)
plt.plot(fsweep, chB)

# %%
E.PS.current = 0
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 E.PS.current = 0
#
# NameError: name 'E' is not defined

# %%
E.PS.current = 0

# %%
import numpy as np

# %%
a = np.array([1, 5, 7, 11])

# %%
a * 2
# Out:
# array([ 2, 10, 14, 22])

# %%
a[0:1]
# Out:
# array([1])
